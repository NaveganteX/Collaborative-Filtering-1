# %% [markdown]
# # Section 6 Naive Collaborative Filtering

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter
from surprise import Dataset
from surprise import Reader
import os
from surprise.model_selection import KFold
from surprise.prediction_algorithms.knns import KNNWithMeans
from surprise import accuracy
from surprise.prediction_algorithms.predictions import Prediction
from collections import defaultdict

#split to 10 folds
k_fold = KFold(n_splits=10)

# make sure to have ml-latest-small in the same folder
file_path = os.path.expanduser('ml-latest-small/ratings.csv')
reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1, rating_scale= (0,5)) 
dataset = Dataset.load_from_file(file_path, reader=reader)

# %% [markdown]
# # Question 30

# %%
data = {}
avg_user_rating = {}
rmse = []

for i in dataset.raw_ratings:
    data.setdefault(i[0], []).append(i[2])

for i, j in data.items():
    avg_user_rating[i] = np.average(j)

for k in range(2,102,2):
    rmse_temp = []
    knn_with_means = KNNWithMeans(k = k, sim_options = {'name':'pearson', 'user_based': True})
    
    for trainset, testset in k_fold.split(dataset):
        knn_with_means.fit(trainset)
        knn_pred = knn_with_means.test(testset)
        pred = []
       
        for i in knn_pred:
            pred.append(Prediction(i[0], i[1], i[2], avg_user_rating[i[0]], i[4]))
        
        rmse_temp.append(accuracy.rmse(pred))
    rmse.append(np.mean(rmse_temp))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3641
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3638
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3531
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3638
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3753
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3817
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3657
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3771
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3528
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3733
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3519
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3729
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3737
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3803
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3738
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3723
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3589
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3793
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3841
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3700
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3668
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3638
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3505
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3520
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3515
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3805
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3801
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3835
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3700
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3730
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3473
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3553
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3738
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3774
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3752
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3632
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3569
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3691
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3822
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3647
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3662
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3699
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3707
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3675
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3447
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3780
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3807
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3776
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3821
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3568
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3699
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3850
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3754
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3484
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3627
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3664
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3704
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3893
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3769
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3675
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3511
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3617
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3773
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3727
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3738
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3817
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3654
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3554
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3516
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3518
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3704
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3825
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3663
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3543
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3641
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3612
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3898
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3875
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3808
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3735
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3638
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3803
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3602
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3691
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3595
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3547
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3714
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3510
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3705
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3736
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3820
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3595
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3487
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3691
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3817
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3801
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3767
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3570
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3566
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3808
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3762
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3584
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3593
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3724
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3844
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3546
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3613
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3792
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3632
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3552
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3791
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3864
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3810
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3876
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3747
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3567
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3588
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3622
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3688
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3625
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3628
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3710
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3870
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3470
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3820
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3849
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3833
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3619
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3605
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3734
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3619
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3756
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3670
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3590
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3621
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3535
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3579
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3682
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3778
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3784
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3892
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3576
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3611
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3641
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3774
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3792
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3854
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3621
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3778
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3512
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3607
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3738
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3543
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3816
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3733
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3734
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3508
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3836
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3628
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3825
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3857
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3796
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3465
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3625
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3800
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3764
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3641
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3811
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3495
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3500
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3607
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3827
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3771
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3617
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3545
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3695
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3677
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3774
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3923
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3777
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3612
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3620
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3601
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3676
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3800
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3675
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3639
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3584
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3633
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3575
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3788
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3846
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3795
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3601
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3551
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3701
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3759
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3707
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3779
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3549
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3710
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3527
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3669
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3740
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3816
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3714
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3482
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3886
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3909
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3437
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3547
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3864
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3774
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3675
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3768
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3581
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3490
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3872
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3607
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3537
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3655
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3820
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3639
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3712
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3817
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3760
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3618
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3871
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3484
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3546
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3735
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3730
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3592
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3528
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3591
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3843
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3960
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3631
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3586
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3739
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3640
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3744
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3535
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3764
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3789
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3705
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3748
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3835
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3627
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3590
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3795
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3669
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3815
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3855
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3535
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3615
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3498
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3838
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3605
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3646
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3688
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3662
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3669
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3729
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3865
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3779
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3518
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3611
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3921
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3578
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3886
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3493
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3766
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3905
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3628
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3633
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3513
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3675
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3771
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3842
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3527
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3795
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3759
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3730
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3577
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3818
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3608
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3700
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3660
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3688
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3678
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3752
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3660
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3765
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3754
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3716
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3792
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3632
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3722
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3573
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3790
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3567
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3779
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3655
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3663
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3739
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3752
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3603
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3556
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3716

# %%
k = np.arange(2,102,2)
plt.plot(k, rmse)
plt.title('RMSE')
plt.xlabel('Iteration')
plt.ylabel('RMSE')
axes = plt.gca()
axes.set_ylim([1.35, 1.4])
plt.show()

print('Mean RSME:', np.mean(rmse))
# Out:
# Mean RSME: 1.3688000220292977

# %% [markdown]
# # Question 31

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratingFreq = dict(Counter(ratings.iloc[:,1].values))

# popular movies 
def trim(testset):
    for i in testset:
        if (ratingFreq[int(i[1])] <= 2): 
            testset.remove(i)
    return testset

data = {}
avg_user_rating = {}
rmse = []

for i in dataset.raw_ratings:
    data.setdefault(i[0], []).append(i[2])

for i, j in data.items():
    avg_user_rating[i] = np.average(j)

for k in range(2,102,2):
    rmse_temp = []
    knn_with_means = KNNWithMeans(k = k, sim_options = {'name':'pearson', 'user_based': True})
    
    for trainset, testset in k_fold.split(dataset):
        knn_with_means.fit(trainset)
        testset = trim(testset) #trim step
        knn_pred = knn_with_means.test(testset)
        pred = []
       
        for i in knn_pred:
            pred.append(Prediction(i[0], i[1], i[2], avg_user_rating[i[0]], i[4]))
        
        rmse_temp.append(accuracy.rmse(pred))
    rmse.append(np.mean(rmse_temp))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3664
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3525
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3291
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3502
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3569
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3862
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3475
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3499
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3612
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3500
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3568
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3488
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3608
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3619
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3432
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3586
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3678
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3484
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3554
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3640
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3627
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3367
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3766
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3727
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3508
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3640
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3619
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3617
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3435
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3534
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3679
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3459
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3578
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3583
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3444
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3454
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3653
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3611
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3890
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3474
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3502
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3543
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3793
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3596
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3581
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3603
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3540
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3557
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3590
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3764
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3653
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3567
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3416
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3581
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3840
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3511
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3389
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3744
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3329
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3575
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3605
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3854
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3552
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3592
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3583
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3570
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3420
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3420
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3922
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3447
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3507
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3416
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3510
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3444
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3836
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3689
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3438
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3613
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3552
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3443
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3417
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3677
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3504
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3616
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3769
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3551
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3669
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3554
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3541
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3631
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3451
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3650
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3625
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3583
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3485
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3513
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3509
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3593
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3619
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3792
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3605
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3641
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3639
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3688
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3475
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3454
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3461
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3496
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3548
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3565
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3682
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3564
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3473
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3500
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3766
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3487
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3654
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3511
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3589
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3519
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3655
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3516
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3423
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3539
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3491
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3595
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3682
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3638
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3591
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3766
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3439
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3481
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3515
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3662
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3570
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3597
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3504
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3668
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3608
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3612
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3411
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3716
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3617
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3700
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3679
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3435
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3530
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3450
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3520
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3699
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3453
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3613
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3602
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3506
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3494
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3794
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3613
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3748
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3485
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3741
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3655
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3521
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3625
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3590
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3458
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3601
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3472
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3570
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3799
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3478
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3511
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3525
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3581
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3466
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3639
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3595
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3521
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3669
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3683
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3687
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3612
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3363
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3627
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3554
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3527
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3362
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3597
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3788
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3679
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3584
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3472
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3478
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3557
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3541
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3623
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3683
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3386
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3552
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3664
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3403
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3563
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3687
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3669
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3367
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3558
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3687
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3526
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3663
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3536
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3691
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3540
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3545
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3612
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3611
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3484
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3388
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3701
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3591
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3442
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3547
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3492
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3552
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3760
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3740
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3596
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3682
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3489
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3456
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3536
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3559
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3705
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3592
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3500
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3657
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3555
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3656
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3567
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3525
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3643
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3617
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3429
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3858
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3608
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3677
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3360
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3382
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3655
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3454
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3678
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3710
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3724
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3473
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3576
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3474
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3620
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3701
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3495
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3484
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3530
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3724
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3517
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3593
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3556
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3642
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3520
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3414
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3654
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3794
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3638
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3633
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3539
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3474
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3735
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3531
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3546
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3536
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3576
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3670
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3593
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3625
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3463
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3424
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3489
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3621
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3718
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3714
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3700
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3417
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3539
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3568
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3800
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3541
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3514
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3691
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3556
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3713
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3434
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3574
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3620
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3464
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3456
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3657
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3815
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3604
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3565
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3663
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3436
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3558
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3718
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3676
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3581
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3724
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3619
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3416
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3668
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3489
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3517
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3512
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3842
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3601
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3607
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3487
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3688
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3596
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3507
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3513
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3570
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3347
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3785
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3654
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3544
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3748
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3467
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3778
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3503
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3691
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3403
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3631
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3650
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3488
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3526
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3631
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3509
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3404
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3517
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3718
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3846
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3466
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3561
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3605
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3564
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3521
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3551
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3689

# %%
k = np.arange(2,102,2)
plt.plot(k, rmse)
plt.title('RMSE for Popular Items')
plt.xlabel('Iteration')
plt.ylabel('RMSE')
axes = plt.gca()
axes.set_ylim([1.3, 1.4])
plt.show()

print('Mean RSME:', np.mean(rmse))
# Out:
# Mean RSME: 1.3601590560933658

# %% [markdown]
# # Question 32

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratingFreq = dict(Counter(ratings.iloc[:,1].values))

# unpopular movies 
def trim(testset):
    for i in testset:
        if (ratingFreq[int(i[1])] > 2): 
            testset.remove(i)
    return testset

data = {}
avg_user_rating = {}
rmse = []

for i in dataset.raw_ratings:
    data.setdefault(i[0], []).append(i[2])

for k, v in data.items():
    avg_user_rating[k] = np.average(v)

for k in range(2,102,2):
    rmse_temp = []
    knn_with_means = KNNWithMeans(k = k, sim_options = {'name':'pearson', 'user_based': True})
    
    for trainset, testset in k_fold.split(dataset):
        testset = trim(testset) #trim step
        knn_with_means.fit(trainset)
        knn_pred = knn_with_means.test(testset)
        pred = []
       
        for i in knn_pred:
            pred.append(Prediction(i[0], i[1], i[2], avg_user_rating[i[0]], i[4]))
        
        rmse_temp.append(accuracy.rmse(pred))
    rmse.append(np.mean(rmse_temp))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3723
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3747
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3986
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3781
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3818
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3853
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3716
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4040
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3656
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3763
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3871
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3596
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4019
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3926
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3935
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3461
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3998
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3818
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3910
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3870
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3554
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3778
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3716
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3633
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3542
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3880
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3687
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3705
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3825
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3773
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3662
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3653
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3812
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3869
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3718
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3844
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3679
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3842
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3602
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4066
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3885
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3932
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3962
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4022
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3822
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3467
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3588
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3759
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3880
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4113
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3872
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3900
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3740
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3748
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3886
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3687
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3912
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4073
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3470
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3851
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3686
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3760
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3822
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3801
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3876
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3934
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3580
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3714
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4009
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3776
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3879
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3641
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3807
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3928
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4054
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3529
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3829
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3813
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4001
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3476
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4097
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3831
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3876
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3584
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3756
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3729
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3621
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3921
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3705
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3917
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3735
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3932
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3840
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3740
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3522
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3647
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3767
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3920
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3862
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3966
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4101
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3846
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3907
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3931
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3776
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3757
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3932
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3495
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3777
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3722
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3852
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3813
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3695
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3425
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3877
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3722
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3970
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3884
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3922
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3595
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3834
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3890
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3857
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3814
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3692
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3818
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3968
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3814
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3708
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3913
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3816
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3559
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4029
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3762
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3897
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3603
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3896
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3565
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3814
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3938
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3513
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3791
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3909
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3753
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3759
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3919
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3822
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3968
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3767
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3796
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3992
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3777
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3773
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3763
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3961
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3877
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3827
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3783
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3553
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4054
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3586
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3707
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3929
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3476
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3861
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3848
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3549
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3934
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3695
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4152
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3960
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3809
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3744
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3813
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4089
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3977
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4045
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3567
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3927
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3750
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3952
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3506
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3815
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3847
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3842
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3870
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3924
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3828
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3758
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3769
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3858
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3999
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3678
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3775
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4020
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4089
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3961
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3767
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3843
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3604
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3744
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3909
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3597
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3676
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3657
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3971
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3676
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3736
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3741
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3938
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3695
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3830
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3754
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3897
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3815
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3695
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3923
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3693
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4004
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3788
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3768
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4001
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3828
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3677
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3872
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3819
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3632
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3865
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3789
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3611
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3847
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3483
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3945
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3903
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4020
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3597
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3555
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3810
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4032
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4000
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3933
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3963
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3443
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3841
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3854
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3775
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3546
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3778
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3681
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3832
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3763
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3827
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3881
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3809
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3789
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3688
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3819
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3912
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3741
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3953
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3728
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3712
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3607
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3992
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3592
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3707
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3769
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3577
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3851
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3764
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3779
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3730
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4053
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3701
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3651
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3856
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3734
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3891
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3855
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3849
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3973
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3646
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3860
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4020
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3842
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3654
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3931
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3880
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3917
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3767
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3740
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3576
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3439
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3881
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3608
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3924
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3769
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3748
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3888
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3660
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3789
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3837
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3985
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3951
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3831
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3662
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3722
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3576
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3911
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3855
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3789
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3856
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3944
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3631
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3993
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3822
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3800
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3870
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3835
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3461
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3634
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3889
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3657
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3895
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3861
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3623
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3646
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3621
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3924
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3874
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3857
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3877
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3695
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3981
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3611
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3806
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3740
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3735
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3794
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3754
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3796
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3500
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3819
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3667
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4011
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3900
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3829
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3799
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3727
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3683
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3919
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3790
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3713
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3939
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3622
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3570
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4000
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3775
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3867
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3910
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3686
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3809
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3847
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3883
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3697
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3744
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3762
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3875
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3737
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3859
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3942

# %%
k = np.arange(2,102,2)
plt.plot(k, rmse)
plt.title('RMSE for Unpoplular Items')
plt.xlabel('Iteration')
plt.ylabel('RMSE')
axes = plt.gca()
axes.set_ylim([1.3, 1.4])
plt.show()

print('Mean RSME:', np.mean(rmse))
# Out:
# Mean RSME: 1.3772852963989024

# %% [markdown]
# # Question 33

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratingFreq = dict(Counter(ratings.iloc[:,1].values))
avg_user_rating = {}
movieRatings = ratings.iloc[:,1:3].values
var= {}
rmse = []

def trim(testset):
    for i in testset:
        if (ratingFreq[int(i[1])] < 5 or var[int(i[1])] < 2):
            testset.remove(i)
    return testset

data = {}
for i in dataset.raw_ratings:
    data.setdefault(i[0], []).append(i[2])

for i, j in data.items():
    avg_user_rating[i] = np.average(j)
    
data = {}
for i in movieRatings:
    data.setdefault(i[0], []).append(i[1])
    
for i, j in data.items():
    var[i] = np.var(j)
    

for k in range(2,102,2):
    rmse_temp = []
    knn_with_means = KNNWithMeans(k = k, sim_options = {'name':'pearson', 'user_based': True})
    
    for trainset, testset in k_fold.split(dataset):
        testset = trim(testset) #trim step
        knn_with_means.fit(trainset)
        knn_pred = knn_with_means.test(testset)
        pred = []
        for i in knn_pred:
            pred.append(Prediction(i[0], i[1], i[2], avg_user_rating[i[0]], i[4]))
        rmse_temp.append(accuracy.rmse(pred))
    rmse.append(np.mean(rmse_temp))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3919
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3927
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3683
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3705
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3717
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3701
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3957
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3660
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3875
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3643
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3579
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3816
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3586
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3685
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3831
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3714
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3854
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3921
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3766
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3596
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3958
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3514
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3506
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3464
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3568
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3836
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3552
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3704
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3887
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3597
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3778
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3748
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3510
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3708
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3821
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3891
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3617
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3548
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3719
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3850
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3953
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3451
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3509
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3954
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3836
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3542
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3539
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3882
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3859
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3678
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3745
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3840
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4027
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3710
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3364
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3699
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3799
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3899
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3463
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3741
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3765
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3710
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3683
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3793
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4103
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3803
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3673
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3634
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3812
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3573
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3730
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3716
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3522
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3636
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3547
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3627
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3921
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3560
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3616
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3708
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3671
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3998
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3566
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3556
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3526
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3653
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3835
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3556
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3793
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3946
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3955
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3670
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3935
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3537
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3936
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3890
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3578
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3741
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3775
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3604
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3573
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3823
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3425
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3582
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3382
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3986
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3409
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3555
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3500
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3867
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3681
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3560
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3990
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3643
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3752
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3794
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3452
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3604
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3738
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3799
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3908
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3846
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3320
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3629
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3704
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3922
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3786
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3707
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3644
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3678
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3793
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3838
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3897
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3547
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3663
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3887
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3879
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3757
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3737
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3642
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3392
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3528
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3730
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3835
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3879
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3711
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3501
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3515
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3601
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3561
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3916
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3826
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3791
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3562
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3655
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3532
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3692
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3742
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3853
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3830
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3781
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3836
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3803
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3698
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3432
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3836
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3911
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3991
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3396
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3659
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3616
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3727
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3860
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3713
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3753
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3808
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3579
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3882
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3768
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3870
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3649
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3615
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3431
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3880
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3808
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3860
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3861
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3895
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3736
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3532
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3439
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3729
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3547
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3507
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3812
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3502
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3928
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3620
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3802
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3584
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3857
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3584
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3421
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3774
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3799
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3606
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3556
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3777
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3762
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3815
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3460
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3882
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3904
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3805
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3816
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3518
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3870
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3721
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3956
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3832
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3753
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3840
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3936
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3483
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3703
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3804
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3482
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3648
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3634
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3670
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3572
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3459
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3681
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3699
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3762
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3581
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3792
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3736
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3640
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3428
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3640
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3799
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3803
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3831
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3704
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3798
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3631
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3907
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3608
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3796
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3568
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3542
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3630
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3665
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3861
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3963
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3879
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3874
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3878
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3626
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3839
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3674
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3684
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3663
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3387
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3692
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3845
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3616
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3783
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3614
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3739
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3769
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3795
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3573
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4015
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3573
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3731
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3852
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3680
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3624
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3543
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3517
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3646
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3588
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3797
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3512
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3770
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3647
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3676
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3623
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3690
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3810
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3702
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3452
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3755
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3771
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3503
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3761
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3904
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3526
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3827
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3517
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3789
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3727
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3551
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3783
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3824
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4076
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3528
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3856
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3888
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3658
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3793
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3830
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3415
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3725
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3723
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3976
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3589
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3587
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3645
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3956
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3637
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3459
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3880
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3534
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3720
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3610
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3754
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3802
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3787
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3843
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3847
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3534
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3896
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3662
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3722
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3726
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3706
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3609
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3539
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3857
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3904
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3656
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3712
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3571
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3954
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3598
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3970
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3416
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3642
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3811
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3782
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3499
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3767
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3790
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3618
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3627
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3879
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3666
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3592
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3743
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3712
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3715
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3603
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3848
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3546
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3594
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3709
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3733
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3796
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3512
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3749
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3591
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3516
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3539
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3625
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3990
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3652
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3997
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3585
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3729
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3632
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3784
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3732
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3898
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3635
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3496
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3579
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3506
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3915
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3790
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3559
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3746
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3751
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3676
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3815
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3661
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3600
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3800
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3754
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3780
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3792
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3551
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3871
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3696
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3772

# %%
k = np.arange(2,102,2)
plt.plot(k, rmse)
plt.title('RMSE for High Variance Items')
plt.xlabel('Iteration')
plt.ylabel('RMSE')
axes = plt.gca()
axes.set_ylim([1.3, 1.4])
plt.show()

print('Mean RSME:', np.mean(rmse))
# Out:
# Mean RSME: 1.3705433878436304

# %% [markdown]
# # Section 7 Performance Comparison

# %% [markdown]
# # Question 34

# %%
# ROC curves for kNN, NNMF, and MF
# compare performance of the filters

from surprise.model_selection import train_test_split
from surprise import Dataset
from surprise import Reader
import os
from surprise import NMF, SVD
from surprise.prediction_algorithms.knns import KNNWithMeans
from surprise.prediction_algorithms.matrix_factorization import SVD
from sklearn.metrics import roc_curve, auc

threshold = 3
file_path = os.path.expanduser('ml-latest-small/ratings.csv')
reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1, rating_scale= (0,5))
dataset = Dataset.load_from_file(file_path, reader=reader)
trainset, testset = train_test_split(dataset, test_size=0.1)

# KNN
knn = KNNWithMeans(k=20, sim_options={'name': 'pearson'})
knn.fit(trainset)
prediction_knn = knn.test(testset)

true_knn = []
pred_knn = []

for user, item, t, p, x in prediction_knn:
    if t >= threshold:
        true_knn.append(1)
    else:
        true_knn.append(0)
    pred_knn.append(p)

fpr_knn, tpr_knn, _ = roc_curve(true_knn, pred_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)

# NMF
nmf = NMF(n_factors=20)
nmf.fit(trainset)
prediction_nmf = nmf.test(testset)

true_nmf = []
pred_nmf = []

for uid, mid, t, p, misc in prediction_nmf:
    if t >= threshold:
        true_nmf.append(1)
    else:
        true_nmf.append(0)
    pred_nmf.append(p)

fpr_nmf, tpr_nmf, _ = roc_curve(true_nmf, pred_nmf)
roc_auc_nmf = auc(fpr_nmf, tpr_nmf)

# SVD
svd = SVD(n_factors=20)
svd.fit(trainset)
prediction_svd = svd.test(testset)

true_svd = []
pred_svd = []

for uid, mid, t, p, misc in prediction_svd:
    if t >= threshold:
        true_svd.append(1)
    else:
        true_svd.append(0)
    pred_svd.append(p)

fpr_svd, tpr_svd, _ = roc_curve(true_svd, pred_svd)
roc_auc_svd= auc(fpr_svd, tpr_svd)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
plt.plot(fpr_knn, tpr_knn, label= ' kNN: area under curve = %0.4f' % roc_auc_knn)
plt.plot(fpr_nmf, tpr_nmf, label= ' NMF: area under curve = %0.4f' % roc_auc_nmf)
plt.plot(fpr_svd, tpr_svd, label= ' SVD: area under curve = %0.4f' % roc_auc_svd)
plt.title('ROC Curve with Threshold = 3')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.xlim([-0.1, 1.0])
plt.ylim([0.0, 1.05])
plt.legend(loc="lower right")
plt.grid(color='0.7', linestyle='--', linewidth=1)

plt.show()

# %% [markdown]
# As we can observe from the ROC plot, the area under the ROC curve for matrix factorization with SVD is the largest (which has an area of 0.7984) , followed by k-nearest neighbor (0.7878) and matrix factorization with NMF (0.7754). Therefore, we can conclude that matrix factorization with SVD has the best performance among the three algorithms.

# %% [markdown]
# # Section 8 Ranking

# %% [markdown]
# # Question 35

# %% [markdown]
# The precision function calculates the percentage of recommended items that are also liked by users, whereas the recall function calculates the accuracy of the recommendation system by computing the percentage recommended by the system over the total number of liked items defined by the ground truth.
#
# For example, if we assume that the size of recommended set t <= size of ground truth set, and suppose the system recommends items {1, 2, 4} when ground truth is {1, 2, 4, 5}, then precision yields 3/3, whereas recall yields 3/4. This implies that the accuracy of our recommendation system in terms of prediction is 100% (the system did not recommend anything that is not in the ground truth set, so it did not recommend anything that is not actually liked by users), and the accuracy of the system in terms of "completeness" is 75% (only 75% of user liked items are actually included in our recommended item set).

# %% [markdown]
# # Question 36

# %%
def precision_function(prediction, t):
    G = defaultdict(list)
    S = defaultdict(list)
    
    for p in prediction:
        if (p[2] > 3): # set threshold to 3
            G[p[0]].append((p[1], p[2], p[3]))
            
    #drop user if |G| = 0
    for i, j in G.items():
        if (len(G[i]) == 0):
            del G[i]
    
    for p in prediction:
        S[p[0]].append((p[1], p[2], p[3]))
        S[p[0]] = sorted(S[p[0]], key=lambda x: x[2], reverse=True)[:t]
        
    precisions = []
    for i, j in S.items():
        size_S = len(S[i])
        
        # if some user in the test set has rated less than t items, drop user
        if (size_S < t):
            continue
            
        count = 0
        for k in S[i]:
            if (k in G[i]):
                count+=1
        
        precision_temp = count/size_S
        precisions.append(precision_temp)

    result = np.mean(precisions)
    return result

def recall_function(prediction, t):
    G = defaultdict(list)
    S = defaultdict(list)
    
    for p in prediction:
        if (p[2] > 3): # set threshold to 3
            G[p[0]].append((p[1], p[2], p[3]))
            
        S[p[0]].append((p[1], p[2], p[3]))
        S[p[0]] = sorted(S[p[0]], key=lambda x: x[2], reverse=True)[:t]
    
    recalls = []
    for i, j in S.items():
        size_S = len(S[i])
        size_G = len(G[i])
        
        # if some user in the test set has rated less than t items, drop user
        if (size_S < t):
            continue
            
        count = 0
        for item in S[i]:
            if (item in G[i]):
                count+=1
                
        if (size_G != 0):
            recall_temp = count / size_G
            recalls.append(recall_temp)
    
    result = np.mean(recalls)
    return result

# %%
# kNN filter

model = KNNWithMeans(k = 20, sim_options = {'name': 'pearson'})
precision_kNN = []
recall_kNN = []

for t in range(1,26):
    precision_temp = []
    recall_temp = []
    
    for trainset, testset in k_fold.split(dataset):    
        #use k value from Q11, k = 20
        model.fit(trainset)
        prediction = model.test(testset)
        precision_i = precision_function(prediction, t)
        recall_i = recall_function(prediction, t)
        
        precision_temp.append(precision_i)
        recall_temp.append(recall_i)
        
    precision_kNN.append(np.mean(precision_temp))
    recall_kNN.append(np.mean(recall_temp))    

t = np.arange(1,26,1)
plt.plot(t, precision_kNN)
plt.xlabel('t')
plt.ylabel('Average Precision')
plt.title('Average Precision (kNN)')
plt.show()


plt.plot(t, recall_kNN)
plt.xlabel('t')
plt.ylabel('Average Recall')
plt.title('Average Recall (kNN)')
plt.show()


plt.plot(recall_kNN, precision_kNN)
plt.xlabel('Average Recall')
plt.ylabel('Average Precision')
plt.title('Average Precision vs. Average Recall (kNN)')
plt.show()
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# # Question 37

# %%
# NNMF filter

precision_nmf = []
recall_nmf = []
model = NMF(n_factors = 20)

for t in range(1,26):
    print('iteration: ', t)
    precision_temp = []
    recall_temp = []
    
    for trainset, testset in k_fold.split(dataset):    
        model.fit(trainset)
        prediction = model.test(testset)
        precision_i = precision_function(prediction, t)
        recall_i = recall_function(prediction, t)
        
        precision_temp.append(precision_i)
        recall_temp.append(recall_i)
        
    precision_nmf.append(np.mean(precision_temp))
    recall_nmf.append(np.mean(recall_temp))    

t = np.arange(1,26)
plt.plot(t, precision_nmf)
plt.xlabel('t')
plt.ylabel('Average Precision')
plt.title('Average Precision (NNMF)')
plt.show()


plt.plot(t, recall_nmf)
plt.xlabel('t')
plt.ylabel('Average Recall')
plt.title('Average Recall (NNMF)')
plt.show()


plt.plot(recall_nmf, precision_nmf)
plt.xlabel('Average Recall')
plt.ylabel('Average Precision')
plt.title('Average Precision vs. Average Recall (NNMF)')
plt.show()
# Out:
# iteration:  1
# iteration:  2
# iteration:  3
# iteration:  4
# iteration:  5
# iteration:  6
# iteration:  7
# iteration:  8
# iteration:  9
# iteration:  10
# iteration:  11
# iteration:  12
# iteration:  13
# iteration:  14
# iteration:  15
# iteration:  16
# iteration:  17
# iteration:  18
# iteration:  19
# iteration:  20
# iteration:  21
# iteration:  22
# iteration:  23
# iteration:  24
# iteration:  25

# %% [markdown]
# # Question 38

# %%
# MF with bias-based filter

model = SVD(n_factors = 8)
precision_mf = []
recall_mf = []

for t in range(1,26):
    print('iteration: ', t)
    precision_temp = []
    recall_temp = []
    
    for trainset, testset in k_fold.split(dataset):    
        model.fit(trainset)
        prediction = model.test(testset)
        precision_i = precision_function(prediction, t)
        recall_i = recall_function(prediction, t)
        
        precision_temp.append(precision_i)
        recall_temp.append(recall_i)
        
    precision_mf.append(np.mean(precision_temp))
    recall_mf.append(np.mean(recall_temp))    

t = np.arange(1,26,1)
plt.plot(t, precision_mf)
plt.xlabel('t')
plt.ylabel('Average Precision')
plt.title('Average Precision (MF)')
plt.show()


plt.plot(t, recall_mf)
plt.xlabel('t')
plt.ylabel('Average Recall')
plt.title('Average Recall (MF)')
plt.show()


plt.plot(recall_mf, precision_mf)
plt.xlabel('Average Recall')
plt.ylabel('Average Precision')
plt.title('Average Precision vs. Average Recall (MF)')
plt.show()
# Out:
# iteration:  1
# iteration:  2
# iteration:  3
# iteration:  4
# iteration:  5
# iteration:  6
# iteration:  7
# iteration:  8
# iteration:  9
# iteration:  10
# iteration:  11
# iteration:  12
# iteration:  13
# iteration:  14
# iteration:  15
# iteration:  16
# iteration:  17
# iteration:  18
# iteration:  19
# iteration:  20
# iteration:  21
# iteration:  22
# iteration:  23
# iteration:  24
# iteration:  25

# %% [markdown]
# # Question 39

# %%
#plot three curves from kNN, NNMF, and MF on the same plot

plt.plot(recall_kNN, precision_kNN, label = 'kNN')
plt.plot(recall_nmf, precision_nmf, label = 'NNMF')
plt.plot(recall_mf, precision_mf, label = 'MF')
plt.xlabel('Average Recall')
plt.ylabel('Average Precision')
plt.title('Average Precision vs. Average Recall (kNN, NNMF, MF)')
plt.legend()

plt.show()

# %% [markdown]
# Since we want both precision and recall functions to have high values, we can use the area under the curve as a measure to determine the performance of each algorithm implemented in this section. From the plot, we can observe that matrix factorization with SVD yields the best performance, followed by kNN and matrix factorization with NMF. Therefore, we can conclude that, for this dataset, the best recommendation system should implement matrix factorization with SVD.
